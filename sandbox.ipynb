# %%
from pogema.pogema_box import PogemaBox, SampleFactoryPogemaBox
from pogema.envs import GridConfig

class ActionMapping:
    noop: int = 0
    up: int = 1
    down: int = 2
    left: int = 3
    right: int = 4





grid = """
.......#.......
.......#.......
...............
...............
...............
.......#.......
.......#.......
#...####.......
.......###...##
.......#.......
.......#.......
...............
...............
...............
.......#.......
"""

'''
from pogema import pogema_v0, GridConfig

env = pogema_v0(GridConfig(seed=7, num_agents=4, size=12, integration='SampleFactory'))
# env = pogema_v0(GridConfig(integration="SampleFactory"))
env.reset()
env.render()

'''

grid_config = GridConfig(map=grid,
                         num_agents=3,
                         observation_type="POMAPF",
                         seed=2)

env = SampleFactoryPogemaBox(grid_config, num_boxes=1)
env.reset()
env.render()

ac = ActionMapping()

env.step([ac.up, ac.up])

env.reset()
env.render()
# Out:
# built sample factory pogema
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .                                                     .  .  .  .
#  .  .  .  .     .  .  .  .  .  .  .     .  .  .  . |0| .  .     .  .  .  .
#  .  .  .  .     .  .  .  .  .  .  .     .  .  .  .  .  .  .     .  .  .  .
#  .  .  .  .     .  .  .  .  .  .  .  .  .  .  .  .  .  .  .     .  .  .  .
#  .  .  .  .     .  .  .  .  .  .  .  .  .  .  .  .  .  .  .     .  .  .  .
#  .  .  .  .     . |1| .  .  .  .  .  .  .  .  .  .  .  .  .     .  .  .  .
#  .  .  .  .     .  .  .  .  .  .  .     .  .  .  .  .  .  .     .  .  .  .
#  .  .  .  .     .  .  .  .  .  .  .     .  .  .  .  .  .  .     .  .  .  .
# ...
